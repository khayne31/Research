# %%
import numpy as np

x = np.loadtxt("weights_tract.txt")

# %%
x = np.loadtxt("lengths_tract.txt")

# %%
x.shape
# Out:
# (66, 66)

# %%
thirty_rest = np.loadtxt("30rest.txt", float, delimiter = ",")

# %%
thirty_rest
# Out:
# array([[-0.019213 ,  0.39832  ,  0.76035  , ...,  0.32154  ,  0.14884  ,
#         -0.01239  ],
#        [ 0.024214 , -0.23516  , -0.47614  , ..., -0.69366  , -0.36313  ,
#          0.028063 ],
#        [-0.051412 , -0.02052  , -0.0022461, ...,  0.27     ,  0.13797  ,
#         -0.012105 ],
#        ...,
#        [ 0.0029772,  0.11148  ,  0.23889  , ...,  0.40649  ,  0.23497  ,
#          0.0088606],
#        [ 0.025675 ,  0.046782 ,  0.090447 , ..., -0.52382  , -0.27363  ,
#          0.020387 ],
#        [ 0.0068168, -0.16816  , -0.29401  , ..., -0.44056  , -0.23925  ,
#         -0.0040264]])

# %%
thirty_rest.shape
# Out:
# (66, 36000)

# %%
np.reshape(thirty_rest, (66,30, 1200))
# Out:
# array([[[-1.9213e-02,  3.9832e-01,  7.6035e-01, ...,  4.8259e-01,
#           3.0986e-01, -4.7860e-03],
#         [ 9.8779e-03,  1.0824e-01,  2.4544e-01, ..., -1.4156e+00,
#          -8.3614e-01,  1.6154e-02],
#         [-1.7863e-02, -1.1200e-01, -1.8124e-01, ..., -3.4356e-01,
#          -2.4087e-01, -2.4911e-03],
#         ...,
#         [ 1.9815e-02,  9.2445e-01,  1.5818e+00, ...,  6.3453e-01,
#           3.6640e-01, -6.5726e-02],
#         [ 4.8342e-03,  5.5779e-01,  9.9386e-01, ..., -5.4277e-01,
#          -2.9789e-01, -2.3456e-02],
#         [-1.3711e-02,  8.9147e-02,  2.0765e-01, ...,  3.2154e-01,
#           1.4884e-01, -1.2390e-02]],
#
#        [[ 2.4214e-02, -2.3516e-01, -4.7614e-01, ...,  9.8765e-01,
#           5.8650e-01,  3.3178e-02],
#         [-4.8668e-03,  3.9001e-01,  6.8447e-01, ..., -5.0064e-01,
#          -2.5961e-01, -3.7826e-03],
#         [ 2.0298e-02, -2.9040e-01, -5.1543e-01, ...,  1.8496e-01,
#           1.3880e-01,  8.2450e-03],
#         ...,
#         [-2.8212e-02, -8.4754e-01, -1.5550e+00, ...,  7.2076e-02,
#           4.4434e-02,  5.7421e-02],
#         [ 2.5632e-02,  7.6415e-02,  1.3496e-01, ...,  6.4013e-02,
#           2.3267e-02, -2.8853e-02],
#         [ 3.0598e-02, -4.9312e-02, -1.1471e-01, ..., -6.9366e-01,
#          -3.6313e-01,  2.8063e-02]],
#
#        [[-5.1412e-02, -2.0520e-02, -2.2461e-03, ...,  2.2568e+00,
#           1.2926e+00, -5.4111e-03],
#         [ 1.6978e-02,  5.8934e-01,  1.0481e+00, ...,  3.5969e-01,
#           1.4159e-01, -3.9336e-03],
#         [-3.4453e-02, -2.4841e-01, -4.0520e-01, ..., -5.2969e-01,
#          -4.0072e-01, -4.8844e-02],
#         ...,
#         [ 8.9737e-03,  6.9723e-01,  1.1618e+00, ...,  8.5901e-01,
#           5.1857e-01, -5.3321e-02],
#         [-1.3346e-02,  6.9228e-01,  1.2293e+00, ..., -9.3977e-01,
#          -5.3050e-01, -1.3607e-02],
#         [-1.5958e-02, -9.2279e-02, -1.4035e-01, ...,  2.7000e-01,
#           1.3797e-01, -1.2105e-02]],
#
#        ...,
#
#        [[ 2.9772e-03,  1.1148e-01,  2.3889e-01, ..., -1.2707e+00,
#          -6.7265e-01,  4.6753e-02],
#         [ 8.5482e-04, -7.7574e-01, -1.3221e+00, ...,  9.7479e-01,
#           5.0629e-01, -1.6828e-03],
#         [-2.2894e-02,  7.5033e-01,  1.3458e+00, ...,  7.5560e-01,
#           3.6460e-01, -6.3909e-02],
#         ...,
#         [ 2.0550e-02,  4.4373e-01,  8.2793e-01, ...,  1.0255e-01,
#           6.5921e-02, -3.6148e-02],
#         [ 2.3177e-02, -7.6832e-01, -1.4029e+00, ..., -4.8858e-01,
#          -2.5960e-01, -1.4588e-03],
#         [ 1.8058e-02,  9.6748e-02,  1.4466e-01, ...,  4.0649e-01,
#           2.3497e-01,  8.8606e-03]],
#
#        [[ 2.5675e-02,  4.6782e-02,  9.0447e-02, ...,  6.3356e-01,
#           3.7636e-01,  2.6521e-02],
#         [-1.7711e-03,  4.3164e-02,  3.5791e-02, ..., -7.4334e-01,
#          -3.7561e-01,  1.6791e-02],
#         [-1.2740e-03, -1.9545e-01, -3.5355e-01, ...,  9.9463e-01,
#           5.5732e-01, -1.0160e-02],
#         ...,
#         [-3.4921e-02, -6.1221e-01, -1.1353e+00, ...,  4.1103e-01,
#           2.3698e-01,  4.7598e-02],
#         [ 2.3255e-02, -1.6910e-01, -3.2042e-01, ...,  1.2372e-01,
#           6.5554e-02, -9.2903e-03],
#         [ 2.5236e-02, -4.6020e-02, -1.0601e-01, ..., -5.2382e-01,
#          -2.7363e-01,  2.0387e-02]],
#
#        [[ 6.8168e-03, -1.6816e-01, -2.9401e-01, ..., -2.7071e-01,
#          -1.5541e-01,  1.0201e-02],
#         [-1.0067e-02,  1.7994e-01,  3.9580e-01, ..., -1.8798e-02,
#          -5.4106e-02, -4.1603e-02],
#         [-5.2038e-03, -5.7117e-01, -1.1198e+00, ..., -1.4724e-01,
#          -1.0671e-01, -4.1841e-03],
#         ...,
#         [ 5.9270e-02, -1.3074e-01, -3.7418e-01, ..., -1.0113e-01,
#          -5.3987e-03,  1.3309e-03],
#         [ 3.9377e-02, -6.3299e-01, -1.1624e+00, ..., -4.7499e-01,
#          -2.5548e-01, -3.6431e-03],
#         [ 1.1237e-02,  7.5698e-01,  1.4202e+00, ..., -4.4056e-01,
#          -2.3925e-01, -4.0264e-03]]])

# %%
img = np.corrcoef(thirty_rest)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img, cmap = "jet")
plt.clim(-1,1)
plt.show()

# %%
weight_matrix = np.loadtxt("weights_tract.txt")

# %%
all_eigenvalues = np.linalg.eig(weight_matrix)

# %%
eigenvalues = all_eigenvalues[0] #non-unit eigenvectors
sorted_eigenvalues = sorted(eigenvalues, reverse = True)
sorted_eigenvalues
# Out:
# [87.03524699975003,
#  79.51911643721276,
#  68.3464330897028,
#  51.71014006637747,
#  40.746161791150314,
#  35.69132811376007,
#  32.42533696587602,
#  30.31631572696904,
#  23.210872266729915,
#  21.438006081710093,
#  19.142386749256694,
#  16.153462759759886,
#  14.454175801422863,
#  12.915331049488165,
#  12.73976606699159,
#  12.415970357758024,
#  10.844788111889606,
#  9.056649448730436,
#  6.8462711937198115,
#  6.01240356136137,
#  4.881117138840596,
#  4.758719416513648,
#  4.269016964330492,
#  3.2849614230767648,
#  2.9439262585635846,
#  0.4010396245592446,
#  0.1807626661535677,
#  -0.4189126785543632,
#  -0.780134475240446,
#  -1.4121795131549015,
#  -1.5675516659950592,
#  -2.863977520965398,
#  -3.537623016361088,
#  -5.349331341214558,
#  -5.4641328730872605,
#  -5.869575229154473,
#  -6.641373442709361,
#  -7.007257143061037,
#  -7.428542249356081,
#  -7.823305995111843,
#  -8.73672710631035,
#  -9.055647626924584,
#  -9.402600894001766,
#  -9.530507581599696,
#  -10.044288502028197,
#  -10.319830144285863,
#  -11.662816632254065,
#  -12.351980132943838,
#  -13.380251485512508,
#  -13.67513631808602,
#  -13.91927820432038,
#  -14.731666729361075,
#  -15.537315362066561,
#  -17.477189721597647,
#  -18.62494386538131,
#  -19.896221574881693,
#  -22.01444061433477,
#  -22.255008999550334,
#  -24.14488768677152,
#  -25.143195161385353,
#  -27.64000521731428,
#  -29.5458759172771,
#  -33.273303428766724,
#  -34.148721568987305,
#  -61.96467122481664,
#  -67.0992972869291]

# %%
#max_eigenvalue = np.amax(eigenvalues)
eigen_to_divide_by = sorted_eigenvalues[0]

# %%
new_weight_matrix = weight_matrix / eigen_to_divide_by
new_weight_matrix = new_weight_matrix * .99

# %%
identity_matrix = np.identity(66)

# %%
weight_minus_id = np.subtract(new_weight_matrix, identity_matrix)

# %%
dt = .72

#all_rs = [random_vector]
#random_vector = np.zeros(66)

# %%
# all_rs.append(random_vector)   dont know whether or not to include the inital random vector

# %%
from statistics import mean
def formulate(mag: int):
    random_vector = np.random.randn(66)
    all_rs = [random_vector]
    norms = []
    for i in range(1199):
        noise = np.random.randn(66) * mag
        norms.append(np.linalg.norm(noise))
        product = np.matmul(weight_minus_id, random_vector)
        dr_dt = np.add(product, noise)
        dr = dr_dt * dt
        random_vector = np.add(random_vector, dr)
        #all_rs.append(random_vector)
        #all_rs = [random_vector] + all_rs
        all_rs.append(random_vector)
    
    rs_over_time = np.asarray(all_rs)
    rs_over_time_transpose = np.transpose(rs_over_time)
    print(mean(norms))
    return rs_over_time_transpose

# %%
thirty_rest = np.reshape(thirty_rest, (30,66,1200))

# %%
all_data = []
for i in range(20):
    result_at_1200 = formulate((i+1))
    result_img = np.corrcoef(result_at_1200)
    
    norm_list = []
    distance_from_data_coef = np.linalg.norm(np.subtract(img, result_img))
    coef = np.corrcoef(img, result_img)
    coef_norm = np.linalg.norm(coef)
   
    print(coef_norm)
    print(distance_from_data_coef)
    #(distance from, the coeficient matrix, the the factor the noise vector is multiplied by)
    all_data.append((distance_from_data_coef, result_img))
    
    plt.imshow(result_img, cmap = "jet")
    plt.clim(-1,1)
    plt.show()
# Out:
# 8.080832889289049
# 46.911394969884974
# 22.012065554321662
# 16.164627546124656
# 49.15630108896824
# 23.094931490374133
# 24.319290355480838
# 45.49837684149759
# 21.01822019096575
# 32.31006705338961
# 52.152317446880986
# 25.641612467969416
# 40.5028388613372
# 49.126692033803856
# 23.19900292469454
# 48.46582013011271
# 49.29541086904936
# 23.24554436891074
# 56.49424654150673
# 46.140544918494754
# 21.370107379781132
# 65.03215259251269
# 52.10863979759294
# 25.21383262565701
# 72.67866971694467
# 51.450684898205886
# 24.812452926453354
# 80.9293487311648
# 45.197847320525064
# 20.60559132093213
# 88.885036448105
# 45.47664671839356
# 21.095682010417757
# 96.97290786285001
# 46.29066146448681
# 21.367517389680284
# 104.57622614408639
# 47.87519660278778
# 22.05041607487385
# 113.0629344796103
# 48.89235297640639
# 23.06623944190802
# 121.39948028318247
# 49.469215130662555
# 23.267402595696247
# 129.40716758420518
# 49.26484044356917
# 22.668058264949345
# 137.69868553521215
# 44.54139542087159
# 20.11642096752823
# 144.909207363439
# 50.32354373669884
# 24.485146252509328
# 153.40107498145903
# 47.155444428481744
# 21.770217632894315
# 162.6432970812751
# 45.36073231930626
# 20.485250593892047

# %%
closest = sorted(all_data)[0]
print(closest[0])
plt.imshow(closest[1], cmap = "jet")
plt.clim(-1,1)
plt.show()
# Out:
# 20.11642096752823

# %%
np.shape(all_data[1][1])
# Out:
# (66, 66)

# %%
plt.imshow(coef, cmap = "jet")
plt.clim(-1,1)
plt.show()

# %%
distance_from_data_coef
# Out:
# 20.485250593892047

# %%
coef = np.corrcoef(img.flatten(), result_img.flatten())
print(coef)
# Out:
# [[1.         0.37440475]
#  [0.37440475 1.        ]]
